# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("housing.csv")

# %%
def shuffle_and_split(data, ratio):
    np.random.seed(42) # Set seed for reproducibility
    shuffled_indices = np.random.permutation(len(data))#returns shuffled indices
    test_set_size = int(len(data) * ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices],data.iloc[test_indices]

# %%
train, test = shuffle_and_split(df,0.2)

# %%
train.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2919     -119.04     35.37                46.0       1637.0           338.0
# 12257    -117.02     33.81                10.0       6317.0          1335.0
# 3132     -117.99     35.16                15.0       2180.0           416.0
# 14360    -117.22     32.74                41.0       2621.0           542.0
# 1007     -121.75     37.68                35.0       1755.0           299.0
#
#        population  households  median_income  median_house_value  \
# 2919        714.0       297.0         2.1818             75300.0
# 12257      2625.0      1094.0         2.3000            108900.0
# 3132        960.0       370.0         2.8750             87800.0
# 14360      1074.0       471.0         2.4016            287500.0
# 1007        702.0       263.0         5.2443            183400.0
#
#       ocean_proximity
# 2919           INLAND
# 12257          INLAND
# 3132           INLAND
# 14360      NEAR OCEAN
# 1007           INLAND
